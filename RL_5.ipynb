# %%
import numpy as np

# %%
np.random.seed(1)

# %%
#1000 random integers between  0 and 5
x=np.random.randint(0,50,1000)

# %%
x
# Out:
# array([43, 43, 10, 34, 33, 11,  2, 10, 27,  5, 26,  3, 31, 11,  3,  1, 13,
#        17,  8, 38,  4,  6, 12,  9,  5, 15, 20, 31, 26,  7, 43,  2, 32, 46,
#        11, 18, 44,  0, 37, 47,  9, 26, 20, 15,  1,  5,  2, 25, 28, 19, 43,
#        17,  5, 45, 15, 10, 29, 17, 17, 46,  7, 17, 22,  0,  7, 29, 28, 35,
#        43, 34, 40,  5, 28, 41, 34, 34, 19, 13, 37, 25,  4, 43, 11, 29, 12,
#        25, 32, 40, 42, 23, 25, 43, 40, 24, 31, 28,  0, 22, 24, 22, 10, 43,
#        31,  9, 39,  6, 30,  3, 18, 12,  9, 10, 27,  1, 21, 42,  6,  9, 36,
#        23,  8, 23, 18, 42, 21,  3, 14, 20, 43, 21,  9, 42,  2, 20, 43, 16,
#        13, 42, 35, 11, 28, 42, 21, 34, 44, 42, 28, 18,  8, 30,  0, 13, 18,
#        38, 11, 19, 12,  4, 45, 25, 40, 35,  5, 31, 29,  2, 32,  7, 29,  8,
#        27, 33, 29,  4, 38, 33,  9,  3, 14, 20, 35, 28, 45, 28,  4, 15, 11,
#        31, 36, 12, 38, 19, 16, 47, 36, 10,  6, 26, 36, 30, 35,  0, 38, 18,
# ...

# %%
y=np.random.randint(0,50,1000)

# %%
y
# Out:
# array([37, 16, 25, 43, 46,  7, 43,  0, 14, 14, 33, 46,  0, 14,  2, 35, 31,
#        39,  7,  7, 16,  2,  5, 38, 15, 14, 40, 13, 12, 37, 11, 15, 31, 46,
#        49, 34,  6, 42,  5, 21, 43, 44,  6,  8, 12, 46, 46, 18,  7, 29, 18,
#         9, 46, 22, 20, 33, 47, 24,  9, 12, 23, 45, 36, 23, 39, 37,  6, 43,
#         1, 19, 29, 48, 45,  8, 34, 29,  0, 15, 19,  4,  7,  1,  8, 26, 40,
#        25, 32,  6, 32,  7, 38, 17, 29, 38,  3, 10, 27, 16, 49, 43, 46, 42,
#         6,  8, 31, 25, 34, 33, 32, 44,  6,  5, 37, 30, 24, 46, 20, 22,  0,
#         5, 22, 27, 39, 37, 25, 48, 36,  0, 45, 38, 32,  5, 15,  5, 33,  0,
#        12, 16, 32, 33, 16, 41, 12, 21, 10, 17, 14,  7, 20, 29, 12,  7,  6,
#        18,  0, 42, 44,  5, 11, 47, 24, 34, 14, 38, 24, 42, 33, 24,  3, 41,
#        30, 39, 22, 38, 41, 32, 27, 27, 18, 33, 36, 44,  6, 38, 45, 48, 34,
#        31, 47, 34,  7, 42, 20, 49, 26, 22,  2, 41,  0, 28, 39,  5,  8,  9,
# ...

# %%
pearsons_coefficient = np.corrcoef(x, y)

# %%
pearsons_coefficient
# Out:
# array([[ 1.       , -0.0141417],
#        [-0.0141417,  1.       ]])

# %%
y=x+np.random.normal(0,10,1000)

# %%
y
# Out:
# array([ 4.69655194e+01,  5.01906468e+01,  2.96788592e+01,  3.08008235e+01,
#         3.84531264e+01,  1.65797657e+01, -6.71388984e+00,  2.83071738e+00,
#         3.83955138e+01,  2.67767658e+00,  3.32153960e+01,  2.17773543e+00,
#         4.33992496e+01, -4.29971237e+00,  2.51461548e+00, -5.05352687e+00,
#         1.69887689e+01, -3.48188246e+00,  1.50284120e+00,  3.42976052e+01,
#         1.62970103e+01,  1.74107534e+01,  1.71524290e+01,  1.37085898e+01,
#        -6.56896177e+00,  2.07457060e+01,  1.46499467e+01,  1.53391158e+01,
#         1.14248945e+01,  3.40022471e+01,  5.52979886e+01,  8.22454563e-01,
#         3.40989052e+01,  4.84524074e+01,  1.28941722e+01,  2.80779244e+01,
#         4.49902955e+01,  4.31306687e+00,  2.07849672e+01,  5.63275868e+01,
#         5.58170280e+00,  2.73825052e+01,  9.65156892e+00,  1.99468773e+01,
#        -2.55604992e+00,  3.76035928e+00, -9.98599833e+00,  2.53139492e+01,
# ...

# %%
np.corrcoef(x,y) # strongly corelated
# Out:
# array([[1.        , 0.80974455],
#        [0.80974455, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
plt.scatter(x,y)
plt.show()

# %%
y=100-x+np.random.normal(0,10,1000)
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.80445381],
#        [-0.80445381,  1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
y
# Out:
# array([ 63.52919655,  36.32826112, 101.05031309,  71.93613431,
#         69.04058494, 100.69738156,  85.40255092,  93.99967828,
#         67.45158859,  90.61003855,  65.3370115 ,  94.27222089,
#         91.55804915,  90.83635358,  93.57511263,  90.69544406,
#         87.46335153,  75.27209651, 104.00151214,  77.62025669,
#         90.27407459, 100.79638516,  72.87810647, 100.06385255,
#         92.37164396,  79.44966082,  74.90045465,  71.90671684,
#         67.91614867, 104.78006858,  56.90338045, 106.82889558,
#         64.80795903,  58.25680598,  74.99708937,  68.03446015,
#         53.15792898,  93.22440634,  58.66071037,  73.71426829,
#         87.41153792,  79.90830409,  66.32992812,  73.95253363,
#         85.6368802 ,  97.21752327, 110.62283057,  57.12298102,
#         72.39418333,  71.41232634,  52.1657567 ,  75.47221352,
#         97.99301601,  63.7020378 ,  85.96664741,  94.49482235,
#         70.76890645,  81.65637531, 109.51768695,  47.54269031,
# ...

# %%
x=np.random.randint(0,50,1000)
y=np.random.randint(0,50,1000)
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.01291696],
#        [0.01291696, 1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
df=pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=100-df['a']+np.random.normal(0,5,1000)
df['d']=np.random.normal(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.830876 -0.948723 -0.021530
# b  0.830876  1.000000 -0.791094 -0.008096
# c -0.948723 -0.791094  1.000000  0.019217
# d -0.021530 -0.008096  0.019217  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
# Out:
# C:\Users\Mudit\AppData\Local\Temp/ipykernel_18112/2775672338.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
